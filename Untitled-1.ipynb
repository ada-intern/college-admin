# %% [markdown]
# # Pushing an Existing Repository to Git
#
# Here are the commands to push an existing local repository to a remote Git server (like GitHub, GitLab, or Bitbucket).

# %%
# Initialize Git repository (if not already initialized)
git init

# Add all files to staging
git add .

# Commit the files
git commit -m "First commit"

# Add the remote repository URL (replace with your repository URL)
git remote add origin https://github.com/ada-intern/college-admin.git

# Push to remote repository
git push -u origin main  # Use 'master' instead of 'main' for older repositories

# %% [markdown]
# Make sure to:
# 1. Replace `<repository-url>` with your actual remote repository URL
# 2. If you get an error about the main/master branch, use whichever is configured in your remote repository
# 3. If prompted, enter your Git credentials
